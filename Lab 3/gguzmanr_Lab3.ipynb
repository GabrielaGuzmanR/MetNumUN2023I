# %% [markdown]
# **Perfil Linkedln**

# %% [markdown]
# Link: www.linkedin.com/in/gabriela-guzmán-3841a6267

# %% [markdown]
# **First Certificate**

# %% [markdown]
# Link: https://courses.cognitiveclass.ai/certificates/d54bd1b39d314f8b96484fd24a4b4bac

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Second Certificate**

# %% [markdown]
# Link: https://courses.cognitiveclass.ai/certificates/82e1d4385129488383ab0083621436c6

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Third Certificate**

# %% [markdown]
# Link: https://courses.cognitiveclass.ai/certificates/9cff4f09a52c494db72cb039d70eeb99

# %% [markdown]
# ![image.png](data:image/png;base64,...)
